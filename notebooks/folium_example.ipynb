# %%
# If you've git cloned this repo, run this cell to add `geostructures` to your python path
import sys
sys.path.insert(0, '../')

# %%
import datetime as dt
from geostructures import Coordinate, GeoPoint, GeoCircle
from geochron.visualization.folium import timehex_styledict, timehex_backgroundata
from geochron import convert_timehex
from geostructures.collections import  Track
from geostructures.geohash import H3Hasher

hasher = H3Hasher(resolution=10)

# %%
track = Track(
    [
        GeoPoint(Coordinate(-0.104154, 51.511920), dt=dt.datetime(2020, 1, 1, 8, 5)),
        GeoCircle(Coordinate(-0.096533, 51.511903),100, dt=dt.datetime(2020, 1, 1, 9, 23)),
        GeoCircle(Coordinate(-0.096533, 51.511903),1000, dt=dt.datetime(2020, 1, 6, 9, 27)),
        GeoPoint(Coordinate(-0.083765, 51.514423), dt=dt.datetime(2020, 1, 1, 9, 44)),
        GeoPoint(Coordinate(-0.087478, 51.508595), dt=dt.datetime(2020, 1, 1, 10, 5)),
        GeoPoint(Coordinate(-0.087478, 51.508595), dt=dt.datetime(2020, 1, 1, 11, 7)),
    ]
)

# %%
timehex_output = convert_timehex(fcol=track,
time_delta= dt.timedelta(hours=1), hash_func= hasher.hash_collection)

# %%
import folium
import pandas as pd
from folium.plugins import TimeSliderChoropleth
from datetime import datetime, timedelta


# Create the map
m = folium.Map(location=[51.511920, -10.0369], zoom_start=7)

# Add the TimeSliderChoropleth
TimeSliderChoropleth(
    data = timehex_backgroundata(timehex_output),
    styledict = timehex_styledict(timehex_output),\
).add_to(m)



m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de23a6315884ea47fb821d8e157d2235 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://d3js.org/d3.v4.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de23a6315884ea47fb821d8e157d2235&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de23a6315884ea47fb821d8e157d2235 = L.map(
#                 &quot;map_de23a6315884ea47fb821d8e157d2235&quot;,
#                 {
#                     center: [51.51192, -10.0369],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82fc070eba85143057d2296130225db9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_82fc070eba85143057d2296130225db9.addTo(map_de23a6315884ea47fb821d8e157d2235);
#
#
#         {
#             let timestamps = [1577865900, 1577869500, 1577873100, 1577876700, 1577880300, 1577883900, 1577887500, 1577891100, 1577894700, 1577898300, 1577901900, 1577905500, 1577909100, 1577912700, 1577916300, 1577919900, 1577923500, 1577927100, 1577930700, 1577934300, 1577937900, 1577941500, 1577945100, 1577948700, 1577952300, 1577955900, 1577959500, 1577963100, 1577966700, 1577970300, 1577973900, 1577977500, 1577981100, 1577984700, 1577988300, 1577991900, 1577995500, 1577999100, 1578002700, 1578006300, 1578009900, 1578013500, 1578017100, 1578020700, 1578024300, 1578027900, 1578031500, 1578035100, 1578038700, 1578042300, 1578045900, 1578049500, 1578053100, 1578056700, 1578060300, 1578063900, 1578067500, 1578071100, 1578074700, 1578078300, 1578081900, 1578085500, 1578089100, 1578092700, 1578096300, 1578099900, 1578103500, 1578107100, 1578110700, 1578114300, 1578117900, 1578121500, 1578125100, 1578128700, 1578132300, 1578135900, 1578139500, 1578143100, 1578146700, 1578150300, 1578153900, 1578157500, 1578161100, 1578164700, 1578168300, 1578171900, 1578175500, 1578179100, 1578182700, 1578186300, 1578189900, 1578193500, 1578197100, 1578200700, 1578204300, 1578207900, 1578211500, 1578215100, 1578218700, 1578222300, 1578225900, 1578229500, 1578233100, 1578236700, 1578240300, 1578243900, 1578247500, 1578251100, 1578254700, 1578258300, 1578261900, 1578265500, 1578269100, 1578272700, 1578276300, 1578279900, 1578283500, 1578287100, 1578290700, 1578294300, 1578297900, 1578301500];
#             let styledict = {&quot;8a194ad30087fff&quot;: {&quot;1577865900&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577869500&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577873100&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577876700&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577880300&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577883900&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577887500&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577891100&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577894700&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577898300&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577901900&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577905500&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577909100&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577912700&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577916300&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577919900&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577923500&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577927100&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577930700&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577934300&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577937900&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577941500&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577945100&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577948700&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577952300&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577955900&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577959500&quot;: {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 0}, &quot;1577963100&quot;: {&q
